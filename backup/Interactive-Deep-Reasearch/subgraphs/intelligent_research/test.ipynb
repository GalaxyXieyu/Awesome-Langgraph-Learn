# %%
from configparser import SectionProxy

from langchain_core.callbacks import streaming_stdout
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import HumanMessage
import time
from graph import create_intelligent_research_graph

workflow = create_intelligent_research_graph()
checkpointer = InMemorySaver()
app = workflow.compile(checkpointer=checkpointer)


topic="人工智能发展全景分析",
workflow = create_intelligent_research_graph()
checkpointer = InMemorySaver()
app = workflow.compile(checkpointer=checkpointer)

sections = [
    {
        "id": "section_1",
        "title": "人工智能技术发展现状",
        "description": "深入分析当前人工智能技术的发展水平、主要应用领域和技术突破"
    },
    {
        "id": "section_2",
        "title": "AI市场竞争格局",
        "description": "研究全球AI市场的竞争态势、主要玩家和市场份额分布"
    },
    {
        "id": "section_3",
        "title": "未来发展趋势预测",
        "description": "基于当前技术发展和市场动态，预测AI技术的未来发展方向"
    }
]
# 初始化状态
initial_state = {
    "messages": [HumanMessage(content=f"开始研究: {topic}")],
    "user_input": f"研究主题: {topic}",
    "topic": topic,
    "sections": sections,
    "current_section_index": 0,
    "research_results": {},
    "writing_results": {},
    "polishing_results": {},
    "final_report": {},
    "execution_path": [],
    "iteration_count": 0,
    "max_iterations": 10,
    "next_action": "",
    "task_completed": False,
    "error_log": []
}

# 配置
config = {"configurable": {"thread_id": f"research_{int(time.time())}"}}

# 执行
start_time = time.time()
# result = await app.astream(initial_state, config=config)

async for chunk in app.astream(initial_state, config=config,stream_mode = ["messages"]):
    print(chunk)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpcore/_async/connection.py:101, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return await self._connection.handle_async_request(request)
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpcore/_async/connection.py:78, in AsyncHTTPConnection.handle_async_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = await self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpcore/_async/connection.py:124, in AsyncHTTPConnection._connect(self, request)
#     123 async with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = await self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpcore/_backends/auto.py:31, in AutoBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      30 await self._init_backend()
# ---> 31 return await self._backend.connect_tcp(
#      32     host,
#      33     port,
#      34     timeout=timeout,
#      35     local_address=local_address,
#      36     socket_options=socket_options,
#      37 )
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpcore/_backends/anyio.py:113, in AnyIOBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     108 exc_map = {
#     109     TimeoutError: ConnectTimeout,
#     110     OSError: ConnectError,
#     111     anyio.BrokenResourceError: ConnectError,
#     112 }
# --> 113 with map_exceptions(exc_map):
#     114     with anyio.fail_after(timeout):
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/openai/_base_client.py:1526, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1525 try:
# -> 1526     response = await self._client.send(
#    1527         request,
#    1528         stream=stream or self._should_stream_response_body(request=request),
#    1529         **kwargs,
#    1530     )
#    1531 except httpx.TimeoutException as err:
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpx/_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpx/_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpx/_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpx/_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpx/_transports/default.py:393, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
# --> 393 with map_httpcore_exceptions():
#     394     resp = await self._pool.handle_async_request(req)
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[1], line 62
#      59 start_time = time.time()
#      60 # result = await app.astream(initial_state, config=config)
# ---> 62 async for chunk in app.astream(initial_state, config=config,stream_mode = ["messages"]):
#      63     print(chunk)
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/langgraph/pregel/main.py:2934, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2932 for task in await loop.amatch_cached_writes():
#    2933     loop.output_writes(task.id, task.writes, cached=True)
# -> 2934 async for _ in runner.atick(
#    2935     [t for t in loop.tasks.values() if not t.writes],
#    2936     timeout=self.step_timeout,
#    2937     get_waiter=get_waiter,
#    2938     schedule_task=loop.aaccept_push,
#    2939 ):
#    2940     # emit output
#    2941     for o in _output(
#    2942         stream_mode,
#    2943         print_mode,
#    (...)   2946         asyncio.QueueEmpty,
#    2947     ):
#    2948         yield o
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/langgraph/pregel/_runner.py:401, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     399 # panic on failure or timeout
#     400 try:
# --> 401     _panic_or_proceed(
#     402         futures.done.union(f for f, t in futures.items() if t is not None),
#     403         timeout_exc_cls=asyncio.TimeoutError,
#     404         panic=reraise,
#     405     )
#     406 except Exception as exc:
#     407     if tb := exc.__traceback__:
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/langgraph/pregel/_runner.py:511, in _panic_or_proceed(futs, timeout_exc_cls, panic)
#     509                 interrupts.append(exc)
#     510             elif fut not in SKIP_RERAISE_SET:
# --> 511                 raise exc
#     512 # raise combined interrupts
#     513 if interrupts:
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/langgraph/pregel/_retry.py:137, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     135         break
#     136     else:
# --> 137         return await task.proc.ainvoke(task.input, config)
#     138 except ParentCommand as exc:
#     139     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/langgraph/_internal/_runnable.py:695, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     693     # run in context
#     694     with set_config_context(config, run) as context:
# --> 695         input = await asyncio.create_task(
#     696             step.ainvoke(input, config, **kwargs), context=context
#     697         )
#     698 else:
#     699     input = await step.ainvoke(input, config, **kwargs)
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/langgraph/_internal/_runnable.py:463, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     461         await run_manager.on_chain_end(ret)
#     462 else:
# --> 463     ret = await self.afunc(*args, **kwargs)
#     464 if self.recurse and isinstance(ret, Runnable):
#     465     return await ret.ainvoke(input, config)
#
# File ~/Documents/Coding/langgraph/backup/Interactive-Deep-Reasearch/subgraphs/intelligent_research/graph.py:111, in supervisor_node(state, config)
#     109 full_response = ""
#     110 chunk_count = 0
# --> 111 async for chunk in llm.astream(formatted_messages, config=config):
#     112     if hasattr(chunk, 'content') and chunk.content:
#     113         content = str(chunk.content)
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:615, in BaseChatModel.astream(self, input, config, stop, **kwargs)
#     613 input_messages = _normalize_messages(messages)
#     614 run_id = "-".join((_LC_ID_PREFIX, str(run_manager.run_id)))
# --> 615 async for chunk in self._astream(
#     616     input_messages,
#     617     stop=stop,
#     618     **kwargs,
#     619 ):
#     620     if chunk.message.id is None:
#     621         chunk.message.id = run_id
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:2709, in ChatOpenAI._astream(self, *args, **kwargs)
#    2707         yield chunk
#    2708 else:
# -> 2709     async for chunk in super()._astream(*args, **kwargs):
#    2710         yield chunk
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:1276, in BaseChatOpenAI._astream(self, messages, stop, run_manager, stream_usage, **kwargs)
#    1274         base_generation_info = {"headers": dict(raw_response.headers)}
#    1275     else:
# -> 1276         response = await self.async_client.create(**payload)
#    1277     context_manager = response
#    1278 try:
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:2454, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2411 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2412 async def create(
#    2413     self,
#    (...)   2451     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    2452 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2453     validate_response_format(response_format)
# -> 2454     return await self._post(
#    2455         "/chat/completions",
#    2456         body=await async_maybe_transform(
#    2457             {
#    2458                 "messages": messages,
#    2459                 "model": model,
#    2460                 "audio": audio,
#    2461                 "frequency_penalty": frequency_penalty,
#    2462                 "function_call": function_call,
#    2463                 "functions": functions,
#    2464                 "logit_bias": logit_bias,
#    2465                 "logprobs": logprobs,
#    2466                 "max_completion_tokens": max_completion_tokens,
#    2467                 "max_tokens": max_tokens,
#    2468                 "metadata": metadata,
#    2469                 "modalities": modalities,
#    2470                 "n": n,
#    2471                 "parallel_tool_calls": parallel_tool_calls,
#    2472                 "prediction": prediction,
#    2473                 "presence_penalty": presence_penalty,
#    2474                 "reasoning_effort": reasoning_effort,
#    2475                 "response_format": response_format,
#    2476                 "seed": seed,
#    2477                 "service_tier": service_tier,
#    2478                 "stop": stop,
#    2479                 "store": store,
#    2480                 "stream": stream,
#    2481                 "stream_options": stream_options,
#    2482                 "temperature": temperature,
#    2483                 "tool_choice": tool_choice,
#    2484                 "tools": tools,
#    2485                 "top_logprobs": top_logprobs,
#    2486                 "top_p": top_p,
#    2487                 "user": user,
#    2488                 "web_search_options": web_search_options,
#    2489             },
#    2490             completion_create_params.CompletionCreateParamsStreaming
#    2491             if stream
#    2492             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2493         ),
#    2494         options=make_request_options(
#    2495             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2496         ),
#    2497         cast_to=ChatCompletion,
#    2498         stream=stream or False,
#    2499         stream_cls=AsyncStream[ChatCompletionChunk],
#    2500     )
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/openai/_base_client.py:1791, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1777 async def post(
#    1778     self,
#    1779     path: str,
#    (...)   1786     stream_cls: type[_AsyncStreamT] | None = None,
#    1787 ) -> ResponseT | _AsyncStreamT:
#    1788     opts = FinalRequestOptions.construct(
#    1789         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1790     )
# -> 1791     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File /opt/anaconda3/envs/langgraph311/lib/python3.11/site-packages/openai/_base_client.py:1558, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1555         continue
#    1557     log.debug("Raising connection error")
# -> 1558     raise APIConnectionError(request=request) from err
#    1560 log.debug(
#    1561     'HTTP Response: %s %s "%i %s" %s',
#    1562     request.method,
#    (...)   1566     response.headers,
#    1567 )
#    1568 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.
# During task with name 'intelligent_supervisor' and id '415201ce-32bb-1f4b-245d-b0ddc1e13711'
