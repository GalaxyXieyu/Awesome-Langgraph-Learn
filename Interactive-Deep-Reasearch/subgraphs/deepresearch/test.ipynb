# %%
from configparser import SectionProxy

from langchain_core.callbacks import streaming_stdout
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import HumanMessage
import time
from graph import create_intelligent_research_graph

workflow = create_intelligent_research_graph()
checkpointer = InMemorySaver()
app = workflow.compile(checkpointer=checkpointer)


topic="人工智能发展全景分析",
workflow = create_intelligent_research_graph()
checkpointer = InMemorySaver()
app = workflow.compile(checkpointer=checkpointer)

sections = [
    {
        "id": "section_1",
        "title": "人工智能技术发展现状",
        "description": "深入分析当前人工智能技术的发展水平、主要应用领域和技术突破"
    },
    {
        "id": "section_2",
        "title": "AI市场竞争格局",
        "description": "研究全球AI市场的竞争态势、主要玩家和市场份额分布"
    },
    {
        "id": "section_3",
        "title": "未来发展趋势预测",
        "description": "基于当前技术发展和市场动态，预测AI技术的未来发展方向"
    }
]
# 初始化状态
initial_state = {
    "messages": [HumanMessage(content=f"开始研究: {topic}")],
    "user_input": f"研究主题: {topic}",
    "topic": topic,
    "sections": sections,
    "current_section_index": 0,
    "research_results": {},
    "writing_results": {},
    "polishing_results": {},
    "final_report": {},
    "execution_path": [],
    "iteration_count": 0,
    "max_iterations": 10,
    "next_action": "",
    "task_completed": False,
    "error_log": []
}

# 配置
config = {"configurable": {"thread_id": f"research_{int(time.time())}"}}

# 执行
start_time = time.time()
# result = await app.astream(initial_state, config=config)

async for chunk in app.astream(initial_state, config=config,stream_mode = ["updates","messages"]):
    print(chunk)
# Out:
# ('messages', (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='```', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='json', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='{\n', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='action', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='":', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='research', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='",\n', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='reason', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='ing', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='":', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='当前', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='章节', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='尚', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='未', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='开始', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='研究', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='，根据', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='决', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='策', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='建议', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='，需要', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='开始', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='对', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='当前', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='章节', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='进行', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='研究', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='。', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='当前', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='尝', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='试', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='次数', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='为', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='/', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='，', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='尚', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='未', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='达到', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='最大', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='尝', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='试', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='次数', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='，因此', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='可以', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='安全', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='地', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='进行', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='第一次', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='研究', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='。",\n', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='target', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='_section', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='":', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='section', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='_', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='",\n', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='quality', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='_feedback', additional_kwargs={}, response_metadata={}, id='run--8b209cf8-54e0-4032-b2b9-82ea17278cbe'), {'thread_id': 'research_1755846925', 'langgraph_step': 1, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'checkpoint_ns': 'intelligent_supervisor:6b881dae-67f9-2191-3e74-6a0aef8f5950', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ...
# ('messages', (AIMessageChunk(content='符合', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='项目', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='要求', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='。",\n', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='confidence', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='":', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='}\n', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='```', additional_kwargs={}, response_metadata={}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('messages', (AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_8458c98457'}, id='run--3e8cc9f7-75cd-48e7-b4a6-fc50fbdf9374'), {'thread_id': 'research_1755846925', 'langgraph_step': 5, 'langgraph_node': 'intelligent_supervisor', 'langgraph_triggers': ('branch:to:intelligent_supervisor',), 'langgraph_path': ('__pregel_pull', 'intelligent_supervisor'), 'langgraph_checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'checkpoint_ns': 'intelligent_supervisor:c09e3134-517c-8cbf-ad3b-5fe15c65ede3', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o-eus2', 'ls_model_type': 'chat', 'ls_temperature': 0.7}))
# ('updates', {'intelligent_supervisor': {'messages': [HumanMessage(content="开始研究: ('人工智能发展全景分析',)", additional_kwargs={}, response_metadata={}, id='6d760a52-0b4b-4cad-8fcc-45dbed3cc23f')], 'user_input': "研究主题: ('人工智能发展全景分析',)", 'topic': ('人工智能发展全景分析',), 'sections': [{'id': 'section_1', 'title': '人工智能技术发展现状', 'description': '深入分析当前人工智能技术的发展水平、主要应用领域和技术突破'}, {'id': 'section_2', 'title': 'AI市场竞争格局', 'description': '研究全球AI市场的竞争态势、主要玩家和市场份额分布'}, {'id': 'section_3', 'title': '未来发展趋势预测', 'description': '基于当前技术发展和市场动态，预测AI技术的未来发展方向'}], 'current_section_index': 1, 'research_results': {'section_1': {'title': '人工智能技术发展现状', 'content': '### 人工智能技术发展现状\n\n#### 当前人工智能技术的发展水平\n\n1. **市场规模和增长**：\n   - 当前人工智能技术正在快速发展，市场规模预计将在未来5年内增长150%。\n\n2. **技术突破**：\n   - 技术的核心突破在于算法优化。最新的基准测试显示，性能提升了300%。这意味着在计算速度和效率上都有显著的提高。\n\n3. **全球市场影响**：\n   - 市场分析师预测，与人工智能技术相关的产业将迎来爆发式增长，全球市场规模预计将达到5000亿美元。\n\n#### 主要应用领域\n\n人工智能技术的应用领域广泛，以下是一些主要的应用领域：\n\n1. **医疗保健**：利用AI进行疾病诊断、个体化治疗方案设计以及药物研发。\n2. **金融服务**：用于风险评估、交易自动化以及客户服务。\n3. **制造业**：在智能制造、自动化生产线的优化以及质量控制中发挥重要作用。\n4. **零售和电子商务**：个性化推荐、库存管理和客户行为分析。\n\n#### 发展趋势\n\n1. **技术成熟度**：\n   - 人工智能技术的成熟度快速提升，市场接受度逐步增长。\n\n2. **政策支持**：\n   - 政策支持力度加大，各国政府纷纷出台促进AI发展的政策，推动产业结构升级。\n\n3. **投资热度**：\n   - 投资热度持续高涨，吸引了大量资本投入，不仅推动了技术创新，也促进了市场的扩大。\n\n### 结论\n\n人工智能技术在2023年的发展可以说是处于一个快速进步和广泛应用的阶段。各项技术的突破和市场的扩张，使得人工智能成为未来几年内最具发展潜力的领域之一。随着技术的成熟和市场的接受度提高，人工智能将在更多领域中发挥其重要作用。', 'timestamp': 1755846934.603032}}, 'writing_results': {'section_1': {'title': '人工智能技术发展现状', 'content': '### 人工智能技术发展现状\n\n#### 当前人工智能技术的发展水平\n\n人工智能技术正处在快速发展的轨道上。根据研究数据，未来五年内，人工智能市场规模预计将增长150%。这种增长不仅反映了技术的不断进步，也显示出市场对人工智能解决方案的需求日益增加。核心技术突破主要体现在算法优化上，最新的基准测试结果显示，算法性能提升了300%，显著提高了计算速度和效率。这些进步为更广泛的应用和更复杂的任务处理提供了可能。\n\n全球市场的影响同样显著。市场分析师预测，人工智能技术将推动相关产业的爆发式增长，全球市场规模预计将达到5000亿美元。这种市场扩张将为各行各业带来新的机会和挑战，也将推动全球经济结构的重塑。\n\n#### 主要应用领域\n\n人工智能技术的应用已经渗透到多个关键行业，其主要应用领域包括：\n\n1. **医疗保健**：\n   - 人工智能在医疗领域的应用主要集中于疾病诊断、个体化治疗方案设计以及药物研发。人工智能可以通过分析大量的医学数据和图像，更快速准确地诊断疾病，并为不同患者量身定制治疗方案。\n\n2. **金融服务**：\n   - 在金融行业，人工智能用于风险评估、交易自动化以及客户服务。通过机器学习算法，金融机构能够更精确地评估信用风险，并优化交易策略以提高盈利能力。\n\n3. **制造业**：\n   - 在制造业中，人工智能促进了智能制造和自动化生产线的优化。质量控制和预测性维护技术的应用，提高了生产效率，降低了成本。\n\n4. **零售和电子商务**：\n   - 人工智能在零售和电子商务中的应用包括个性化推荐、库存管理和客户行为分析。这些技术帮助企业更好地理解客户需求，提升销售效率和客户满意度。\n\n#### 发展趋势\n\n人工智能技术的快速进步带动了以下几大趋势：\n\n1. **技术成熟度**：\n   - 随着技术的不断完善，人工智能的成熟度显著提升，市场接受度也在逐步增长。这为更多企业采用AI技术提供了坚实的基础。\n\n2. **政策支持**：\n   - 全球各国政府正在积极推出促进人工智能发展的政策。这些政策不仅支持技术研发和应用，还推动了相关产业的结构升级。\n\n3. **投资热度**：\n   - 由于其巨大的潜力，人工智能领域吸引了大量的资本投入。投资的持续高涨，不仅推动了技术创新，也促进了市场的扩大，为创业公司和科技巨头的业务扩展提供了动力。\n\n### 结论\n\n2023年，人工智能技术的发展可以说是处于一个快速进步和广泛应用的阶段。技术的不断突破和市场的持续扩张，使得人工智能成为未来几年内最具发展潜力的领域之一。随着技术的成熟和市场的接受度提高，人工智能将在更多领域中发挥其重要作用，继续改变我们生活和工作的方式。', 'word_count': 43, 'timestamp': 1755846943.117651}}, 'polishing_results': {}, 'final_report': {}, 'execution_path': ['intelligent_supervisor', 'research', 'intelligent_supervisor', 'writing', 'intelligent_supervisor'], 'iteration_count': 3, 'max_iterations': 10, 'next_action': 'research', 'task_completed': False, 'error_log': [], 'section_attempts': {'section_1': {'research': 1, 'writing': 1}}}})
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 62
#      59 start_time = time.time()
#      60 # result = await app.astream(initial_state, config=config)
# ---> 62 async for chunk in app.astream(initial_state, config=config,stream_mode = ["updates","messages"]):
#      63     print(chunk)
#
# File /Volumes/DATABASE/opt/miniconda3/envs/langgraph/lib/python3.11/site-packages/langgraph/pregel/main.py:2937, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2935 for task in await loop.amatch_cached_writes():
#    2936     loop.output_writes(task.id, task.writes, cached=True)
# -> 2937 async for _ in runner.atick(
#    2938     [t for t in loop.tasks.values() if not t.writes],
#    2939     timeout=self.step_timeout,
#    2940     get_waiter=get_waiter,
#    2941     schedule_task=loop.aaccept_push,
#    2942 ):
#    2943     # emit output
#    2944     for o in _output(
#    2945         stream_mode,
#    2946         print_mode,
#    (...)   2949         asyncio.QueueEmpty,
#    2950     ):
#    2951         yield o
#
# File /Volumes/DATABASE/opt/miniconda3/envs/langgraph/lib/python3.11/site-packages/langgraph/pregel/_runner.py:368, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     366 end_time = timeout + loop.time() if timeout else None
#     367 while len(futures) > (1 if get_waiter is not None else 0):
# --> 368     done, inflight = await asyncio.wait(
#     369         futures,
#     370         return_when=asyncio.FIRST_COMPLETED,
#     371         timeout=(max(0, end_time - loop.time()) if end_time else None),
#     372     )
#     373     if not done:
#     374         break  # timed out
#
# File /Volumes/DATABASE/opt/miniconda3/envs/langgraph/lib/python3.11/asyncio/tasks.py:428, in wait(fs, timeout, return_when)
#     425     raise TypeError("Passing coroutines is forbidden, use tasks explicitly.")
#     427 loop = events.get_running_loop()
# --> 428 return await _wait(fs, timeout, return_when, loop)
#
# File /Volumes/DATABASE/opt/miniconda3/envs/langgraph/lib/python3.11/asyncio/tasks.py:535, in _wait(fs, timeout, return_when, loop)
#     532     f.add_done_callback(_on_completion)
#     534 try:
# --> 535     await waiter
#     536 finally:
#     537     if timeout_handle is not None:
#
# CancelledError:
