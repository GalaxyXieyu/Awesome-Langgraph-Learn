# %%
import asyncio
import time
from typing import Dict, Any, cast
from graph import create_writing_assistant_graph
from tools import load_knowledge_bases
from langgraph.types import Command

initial_state = {
    "topic": "Python异步编程最佳实践",
    "user_id": "complete_streaming_test",
    "max_words": 600,
    "style": "technical",
    "language": "zh",
    "mode": "interactive",
}
config: Dict[str, Any] = {"configurable": {"thread_id": "complete_streaming_0089"}}


# 生成大纲
graph = create_writing_assistant_graph()
async for chunk in graph.astream(initial_state, cast(Any, config), stream_mode=["custom", "updates"]):
    print(chunk)
# Out:
# INFO:httpx:HTTP Request: POST https://llm.3qiao.vip:23436/v1/chat/completions "HTTP/1.1 200 OK"
# ('custom', {'step': 'outline_generation', 'status': '开始生成大纲', 'progress': 0})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲', 'progress': 50})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': ''}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python'}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异'}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步'}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程'}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳'}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践'}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': []}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': ''}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': ''}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': []}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': ''}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': ''}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括async'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': []}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['async']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': ''}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': ''}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写'}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、'}]}, 'total_chars': 2, 'chunk_count': 1})
# ...
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '处理']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '处理并发']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '正在生成大纲...', 'progress': 100, 'current_content': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '处理并发限制']}]}, 'total_chars': 2, 'chunk_count': 1})
# ('custom', {'step': 'outline_generation', 'status': '大纲生成完成', 'progress': 100, 'outline': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '处理并发限制']}]}, 'validation_score': 100})
# ('updates', {'generate_outline': {'topic': 'Python异步编程最佳实践', 'user_id': 'complete_streaming_test', 'max_words': 600, 'style': 'technical', 'language': 'zh', 'mode': 'interactive', 'messages': [AIMessage(content='已生成文章大纲：\n标题：Python异步编程最佳实践\n章节数：6\n验证分数：100', additional_kwargs={}, response_metadata={})], 'outline': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '处理并发限制']}]}}})
# ('updates', {'__interrupt__': (Interrupt(value={'type': 'outline_confirmation', 'message': '请确认以下大纲是否满意', 'outline': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '处理并发限制']}]}, 'formatted_outline': '文章标题：Python异步编程最佳实践\n\n1. 引言\n   描述：介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。\n   要点：异步编程的定义, 同步与异步的区别, 异步编程的优势\n\n2. Python异步编程基础\n   描述：讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。\n   要点：asyncio库简介, 协程的基本概念, 事件循环的作用, 创建和运行协程\n\n3. 异步IO操作\n   描述：详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。\n   要点：异步文件读写, 异步网络请求, 使用aiohttp库, 错误处理与超时设置\n\n4. 异步编程模式\n   描述：探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。\n   要点：生产者-消费者模式, 任务调度, 并发执行多个任务, 使用asyncio.Queue\n\n5. 性能优化技巧\n   描述：分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。\n   要点：减少阻塞操作, 合理使用线程池, 优化异步函数设计, 性能测试与分析\n\n6. 常见问题与解决方案\n   描述：总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。\n   要点：常见的异步编程错误, 调试异步程序的方法, 避免内存泄漏, 处理并发限制\n\n', 'instructions': "请回复 'yes' 确认继续，或 'no' 重新生成大纲"}, id='db41bbdd627f6afd6b255ad0cc3c9f70'),)})

# %%
# 确认大纲
async for chunk in graph.astream(Command(resume="yes"), cast(Any, config), stream_mode=["custom", "updates"]):
    print(chunk)
# Out:
# ('updates', {'human_confirmation': {'topic': 'Python异步编程最佳实践', 'user_id': 'complete_streaming_test', 'max_words': 600, 'style': 'technical', 'language': 'zh', 'mode': 'interactive', 'outline': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '处理并发限制']}]}, 'messages': [AIMessage(content='已生成文章大纲：\n标题：Python异步编程最佳实践\n章节数：6\n验证分数：100', additional_kwargs={}, response_metadata={}, id='c567df8a-642c-40a9-818d-e52dd6a187f3'), AIMessage(content='用户确认结果: yes', additional_kwargs={}, response_metadata={}, id='b182a795-9996-4fe2-a6c9-4ede6f7509f7')], 'user_confirmation': 'yes'}})
# ('custom', {'step': 'rag_enhancement', 'status': '询问RAG增强权限', 'progress': 0})
# ('updates', {'__interrupt__': (Interrupt(value={'type': 'rag_permission', 'message': '是否需要进行RAG知识库增强？', 'topic': 'Python异步编程最佳实践', 'instructions': "请回复 'yes' 启用RAG增强，'no' 跳过"}, id='7bd2eefb71280f8422f2c3cdf8f351a4'),)})

# %%
# 确认搜索知识库
async for chunk in graph.astream(Command(resume="yes"), cast(Any, config), stream_mode=["custom", "updates"]):
    print(chunk)
# Out:
# ('custom', {'step': 'rag_enhancement', 'status': '询问RAG增强权限', 'progress': 0})
# ('custom', {'step': 'rag_enhancement', 'status': 'RAG增强确认完成', 'progress': 100})
# ('updates', {'rag_enhancement': {'topic': 'Python异步编程最佳实践', 'user_id': 'complete_streaming_test', 'max_words': 600, 'style': 'technical', 'language': 'zh', 'mode': 'interactive', 'outline': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '处理并发限制']}]}, 'user_confirmation': 'yes', 'messages': [AIMessage(content='已生成文章大纲：\n标题：Python异步编程最佳实践\n章节数：6\n验证分数：100', additional_kwargs={}, response_metadata={}, id='c567df8a-642c-40a9-818d-e52dd6a187f3'), AIMessage(content='用户确认结果: yes', additional_kwargs={}, response_metadata={}, id='b182a795-9996-4fe2-a6c9-4ede6f7509f7'), AIMessage(content='RAG增强权限确认结果: yes', additional_kwargs={}, response_metadata={}, id='be39f54d-7b4c-4791-83f7-08a57f4ac8ab')], 'rag_permission': 'yes'}})
# ('updates', {'__interrupt__': (Interrupt(value={'type': 'search_permission', 'message': '是否允许进行联网搜索？', 'topic': 'Python异步编程最佳实践', 'instructions': "请回复 'yes' 允许搜索，'no' 跳过搜索"}, id='3e067d221c030788b1897fd8e6b57ca6'),)})

# %%
# 确认联网搜索并开始生成
async for chunk in graph.astream(Command(resume="yes"), cast(Any, config), stream_mode=["custom", "updates"]):
    print(chunk)
# Out:
# ('updates', {'search_confirmation': {'topic': 'Python异步编程最佳实践', 'user_id': 'complete_streaming_test', 'max_words': 600, 'style': 'technical', 'language': 'zh', 'mode': 'interactive', 'outline': {'title': 'Python异步编程最佳实践', 'sections': [{'title': '引言', 'description': '介绍Python异步编程的基本概念，解释为什么需要异步编程以及其在现代应用程序中的重要性。', 'key_points': ['异步编程的定义', '同步与异步的区别', '异步编程的优势']}, {'title': 'Python异步编程基础', 'description': '讲解Python中实现异步编程的基本方法，包括asyncio库的使用、协程的概念以及事件循环的工作原理。', 'key_points': ['asyncio库简介', '协程的基本概念', '事件循环的作用', '创建和运行协程']}, {'title': '异步IO操作', 'description': '详细介绍如何在Python中进行异步IO操作，包括文件读写、网络请求等，并提供实际代码示例。', 'key_points': ['异步文件读写', '异步网络请求', '使用aiohttp库', '错误处理与超时设置']}, {'title': '异步编程模式', 'description': '探讨常见的异步编程模式，如生产者-消费者模式、任务调度等，并通过代码示例展示这些模式的应用。', 'key_points': ['生产者-消费者模式', '任务调度', '并发执行多个任务', '使用asyncio.Queue']}, {'title': '性能优化技巧', 'description': '分享一些提高异步程序性能的方法，包括减少阻塞操作、合理使用线程池、优化异步函数设计等。', 'key_points': ['减少阻塞操作', '合理使用线程池', '优化异步函数设计', '性能测试与分析']}, {'title': '常见问题与解决方案', 'description': '总结在Python异步编程过程中可能遇到的问题及其解决方法，帮助读者避免常见陷阱。', 'key_points': ['常见的异步编程错误', '调试异步程序的方法', '避免内存泄漏', '处理并发限制']}]}, 'user_confirmation': 'yes', 'rag_permission': 'yes', 'messages': [AIMessage(content='已生成文章大纲：\n标题：Python异步编程最佳实践\n章节数：6\n验证分数：100', additional_kwargs={}, response_metadata={}, id='c567df8a-642c-40a9-818d-e52dd6a187f3'), AIMessage(content='用户确认结果: yes', additional_kwargs={}, response_metadata={}, id='b182a795-9996-4fe2-a6c9-4ede6f7509f7'), AIMessage(content='RAG增强权限确认结果: yes', additional_kwargs={}, response_metadata={}, id='be39f54d-7b4c-4791-83f7-08a57f4ac8ab'), AIMessage(content='搜索权限确认结果: yes', additional_kwargs={}, response_metadata={}, id='e63bb10d-ee13-460f-b5e6-097832336daa')], 'search_permission': 'yes'}})
# ('custom', {'step': 'search_execution', 'status': '开始搜索', 'progress': 0})
# ('custom', {'step': 'search_execution', 'status': '准备搜索 4 个查询', 'progress': 10, 'queries': ['Python异步编程最佳实践', 'Python异步编程最佳实践 引言', 'Python异步编程最佳实践 Python异步编程基础', 'Python异步编程最佳实践 异步IO操作']})
# ('custom', {'step': 'search_execution', 'status': '搜索: Python异步编程最佳实践', 'progress': 10, 'current_query': 'Python异步编程最佳实践'})
# ('custom', {'step': 'search_execution', 'status': '找到 3 个结果', 'progress': 15, 'query_results': 3})
# ('custom', {'step': 'search_execution', 'status': '搜索: Python异步编程最佳实践 引言', 'progress': 27, 'current_query': 'Python异步编程最佳实践 引言'})
# ('custom', {'step': 'search_execution', 'status': '找到 3 个结果', 'progress': 32, 'query_results': 3})
# ('custom', {'step': 'search_execution', 'status': '搜索: Python异步编程最佳实践 Python异步编程基础', 'progress': 45, 'current_query': 'Python异步编程最佳实践 Python异步编程基础'})
