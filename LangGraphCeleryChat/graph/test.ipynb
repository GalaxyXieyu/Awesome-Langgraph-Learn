# %%
import asyncio
import time
from typing import Dict, Any, cast
from graph import create_writing_assistant_graph
from langgraph.checkpoint.redis.aio import AsyncRedisSaver
initial_state = {
    "topic": "Python异步编程最佳实践",
    "user_id": "complete_streaming_test",
    "max_words": 600,
    "style": "technical",
    "language": "zh",
    "mode": "interactive",
    "outline": None,
    "article": None,
    "search_results": [],
    "messages": [],
    "checkpointer": None
}
REDIS_URL = "redis://default:mfzstl2v@dbconn.sealoshzh.site:41277"
config: Dict[str, Any] = {"configurable": {"thread_id": "complete_streaming_0089"}}
async with AsyncRedisSaver.from_conn_string(REDIS_URL) as checkpointer:
    await checkpointer.asetup()

    # 创建并编译图
    workflow = create_writing_assistant_graph()
    graph = workflow.compile(checkpointer=checkpointer)
    async for chunk in graph.astream(initial_state, config, stream_mode=["updates", "custom"]):
        print(chunk)
# Out:
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis client is a standalone client
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis cluster_mode explicitly set to False, skipping detection.
# INFO:httpx:HTTP Request: POST https://llm.3qiao.vip:23436/v1/chat/completions "HTTP/1.1 200 OK"
# ('custom', {'event_type': 'progress_update', 'step': 'outline_generation', 'status': '开始生成大纲', 'progress': 0, 'timestamp': 1754388081.505266})
# ('custom', {'event_type': 'progress_update', 'step': 'outline_generation', 'status': '正在生成大纲', 'progress': 50, 'timestamp': 1754388081.714487})
# ...

# %%
from langgraph.types import Command
from langgraph.checkpoint.redis.aio import AsyncRedisSaver

async with AsyncRedisSaver.from_conn_string(REDIS_URL) as checkpointer:
    await checkpointer.asetup()

    # 创建并编译图
    workflow = create_writing_assistant_graph()
    graph = workflow.compile(checkpointer=checkpointer)

    # 使用 Command 对象进行恢
    chunk_count = 0

    async for chunk in graph.astream(Command(resume="yes"), config, stream_mode=["custom", "updates"]):
        print(chunk)
# Out:
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis client is a standalone client
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis cluster_mode explicitly set to False, skipping detection.
# ...

# %%
from langgraph.types import Command
from langgraph.checkpoint.redis.aio import AsyncRedisSaver

async with AsyncRedisSaver.from_conn_string(REDIS_URL) as checkpointer:
    await checkpointer.asetup()

    # 创建并编译图
    workflow = create_writing_assistant_graph()
    graph = workflow.compile(checkpointer=checkpointer)

    # 使用 Command 对象进行恢
    chunk_count = 0

    async for chunk in graph.astream(Command(resume="yes"), config, stream_mode=["custom", "updates"]):
        print(chunk)
# Out:
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis client is a standalone client
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis cluster_mode explicitly set to False, skipping detection.
# ('custom', {'step': 'rag_enhancement', 'status': '询问RAG增强权限', 'progress': 0})
# ('custom', {'step': 'rag_enhancement', 'status': 'RAG增强确认完成', 'progress': 100})
# ...

# %%
from langgraph.types import Command
from langgraph.checkpoint.redis.aio import AsyncRedisSaver

async with AsyncRedisSaver.from_conn_string(REDIS_URL) as checkpointer:
    await checkpointer.asetup()

    # 创建并编译图
    workflow = create_writing_assistant_graph()
    graph = workflow.compile(checkpointer=checkpointer)

    # 使用 Command 对象进行恢
    chunk_count = 0

    async for chunk in graph.astream(Command(resume="yes"), config, stream_mode=["custom", "updates"]):
        print(chunk)
# Out:
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis client is a standalone client
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis cluster_mode explicitly set to False, skipping detection.
# ...

# %%
from langgraph.types import Command
from langgraph.checkpoint.redis.aio import AsyncRedisSaver

async with AsyncRedisSaver.from_conn_string(REDIS_URL) as checkpointer:
    await checkpointer.asetup()

    # 创建并编译图
    workflow = create_writing_assistant_graph()
    graph = workflow.compile(checkpointer=checkpointer)

    # 使用 Command 对象进行恢
    chunk_count = 0

    async for chunk in graph.astream(Command(resume="yes"), config, stream_mode=["custom", "updates"]):
        print(chunk)
# Out:
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis client is a standalone client
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:redisvl.index.index:Index already exists, not overwriting.
# INFO:langgraph.checkpoint.redis.aio:Redis cluster_mode explicitly set to False, skipping detection.
# ...
